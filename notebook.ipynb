# %% [markdown]
# # Young people survey
# Data from [Kaggle](https://www.kaggle.com/miroslavsabo/young-people-survey)

# %% [markdown]
# ### Import libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('young-people-survey/responses.csv', engine='python')

# %% [markdown]
# ### Check data is read

# %%
data.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock           ...             Age  \
# 0      1.0  5.0   5.0                1.0           ...            20.0
# 1      2.0  3.0   5.0                4.0           ...            19.0
# 2      5.0  3.0   5.0                3.0           ...            20.0
# 3      1.0  2.0   2.0                1.0           ...            22.0
# 4      3.0  5.0   3.0                1.0           ...            20.0
#
#    Height  Weight  Number of siblings  Gender  Left - right handed  \
# ...

# %%
print(data)
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# 5       5.0                       3.0    2.0   3.0      2.0              3.0
# 6       5.0                       5.0    5.0   3.0      1.0              2.0
# 7       5.0                       3.0    3.0   2.0      1.0              2.0
# 8       5.0                       3.0    3.0   1.0      1.0              2.0
# 9       5.0                       3.0    2.0   5.0      2.0              2.0
# 10      5.0                       3.0    3.0   2.0      1.0              2.0
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1010, step=1)

# %%
data.columns[40:140]
# Out:
# Index(['Chemistry', 'Reading', 'Geography', 'Foreign languages', 'Medicine',
#        'Law', 'Cars', 'Art exhibitions', 'Religion', 'Countryside, outdoors',
#        'Dancing', 'Musical instruments', 'Writing', 'Passive sport',
#        'Active sport', 'Gardening', 'Celebrities', 'Shopping',
#        'Science and technology', 'Theatre', 'Fun with friends',
#        'Adrenaline sports', 'Pets', 'Flying', 'Storm', 'Darkness', 'Heights',
#        'Spiders', 'Snakes', 'Rats', 'Ageing', 'Dangerous dogs',
#        'Fear of public speaking', 'Smoking', 'Alcohol', 'Healthy eating',
#        'Daily events', 'Prioritising workload', 'Writing notes', 'Workaholism',
#        'Thinking ahead', 'Final judgement', 'Reliability', 'Keeping promises',
#        'Loss of interest', 'Friends versus money', 'Funniness', 'Fake',
#        'Criminal damage', 'Decision making', 'Elections', 'Self-criticism',
#        'Judgment calls', 'Hypochondria', 'Empathy', 'Eating to survive',
# ...

# %%
data['Education']
# Out:
# 0       college/bachelor degree
# 1       college/bachelor degree
# 2              secondary school
# 3       college/bachelor degree
# 4              secondary school
# 5              secondary school
# 6              secondary school
# 7       college/bachelor degree
# 8              secondary school
# 9              secondary school
# 10             secondary school
# 11               primary school
# 12      college/bachelor degree
# 13             secondary school
# 14      college/bachelor degree
# 15             secondary school
# 16      college/bachelor degree
# 17             secondary school
# 18             secondary school
# 19             secondary school
# 20             secondary school
# 21             secondary school
# 22      college/bachelor degree
# 23             secondary school
# 24             secondary school
# 25             secondary school
# 26      college/bachelor degree
# 27             secondary school
# 28             secondary school
# ...

# %%
data.at[21, 'Education']
# Out:
# 'secondary school'

# %%
data['Education'][21]
# Out:
# 'secondary school'

# %%
data[['Education', 'Age']].head()
# Out:
#                  Education   Age
# 0  college/bachelor degree  20.0
# 1  college/bachelor degree  19.0
# 2         secondary school  20.0
# 3  college/bachelor degree  22.0
# 4         secondary school  20.0

# %%
data.describe()
# Out:
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1007.000000               1008.000000  1006.000000  1005.000000
# mean      4.731877                  3.328373     3.113320     2.288557
# std       0.664049                  0.833931     1.170568     1.138916
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# max       5.000000                  5.000000     5.000000     5.000000
#
#            Country  Classical music      Musical          Pop         Rock  \
# count  1005.000000      1003.000000  1008.000000  1007.000000  1004.000000
# mean      2.123383         2.956132     2.761905     3.471698     3.761952
# std       1.076136         1.252570     1.260845     1.161400     1.184861
# ...

# %%
eduStrList = data['Education'].unique()

# %%
eduStrList
# Out:
# array(['college/bachelor degree', 'secondary school', 'primary school',
#        'masters degree', 'doctorate degree',
#        'currently a primary school pupil', nan], dtype=object)

# %%
dictEduStrList = {
    'currently a primary school pupil' : 1,
    'primary school' : 2, 
    'secondary school' : 3,
    'college/bachelor degree' : 4,
    'masters degree' : 5,
    'doctorate degree' : 6,
               }

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data[['Age','Height', 'Weight']], alpha = .7)
pass

# %%
corrData = data.corr()

# %% [markdown]
# ### Calc attrs which are correlated > 0.5

# %%
for key1 in corrData:
    for key2 in corrData:
        if (corrData[key1][key2] > 0.5 and key1 != key2):
            print(key1, ':', key2)
# Out:
# Classical music : Opera
# Rock : Metal or Hardrock
# Rock : Punk
# Metal or Hardrock : Rock
# Metal or Hardrock : Punk
# Punk : Rock
# Punk : Metal or Hardrock
# Opera : Classical music
# Horror : Thriller
# Thriller : Horror
# Fantasy/Fairy tales : Animated
# Animated : Fantasy/Fairy tales
# Mathematics : Physics
# Physics : Mathematics
# Biology : Chemistry
# Biology : Medicine
# Chemistry : Biology
# Chemistry : Medicine
# Medicine : Biology
# Medicine : Chemistry
# Art exhibitions : Theatre
# Religion : God
# Shopping : Shopping centres
# Shopping : Spending on looks
# Theatre : Art exhibitions
# Storm : Darkness
# Darkness : Storm
# Snakes : Rats
# Rats : Snakes
# Fear of public speaking : Public speaking
# God : Religion
# Public speaking : Fear of public speaking
# Shopping centres : Shopping
# Spending on looks : Shopping
# Height : Weight
# Weight : Height

# %%
plt.plot(data['Height'],data['Weight'], 'o', alpha = 0.4)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('')
pass

# %%
data['Age'] < 20
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12      False
# 13       True
# 14      False
# 15       True
# 16       True
# 17      False
# 18       True
# 19       True
# 20      False
# 21      False
# 22      False
# 23      False
# 24       True
# 25      False
# 26      False
# 27       True
# 28      False
# 29       True
#         ...
# 980      True
# 981      True
# 982      True
# 983     False
# 984     False
# 985     False
# 986      True
# 987     False
# 988      True
# 989     False
# 990     False
# 991     False
# 992     False
# 993     False
# 994     False
# 995      True
# 996     False
# 997      True
# 998     False
# 999      True
# 1000     True
# 1001     True
# 1002    False
# 1003    False
# 1004    False
# 1005    False
# 1006    False
# 1007     True
# 1008    False
# 1009    False
# ...

# %% [markdown]
# ## Preprocessing

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']

# %%
print(categorical_columns)
# Out:
# ['Smoking', 'Alcohol', 'Punctuality', 'Lying', 'Internet usage', 'Gender', 'Left - right handed', 'Education', 'Only child', 'Village - town', 'House - block of flats']

# %%
data = pd.read_csv('young-people-survey/responses.csv', engine='python')

# %%
data = data.drop(['Left - right handed', 'Number of siblings', ''])
